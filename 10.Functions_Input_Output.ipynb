# %% [markdown]
# # 🚀 AE 444 - Computer Programming
# ## Python Basics — Functions: Input & Output
#
# In this notebook, we will explore **functions**, which are reusable blocks of code that perform a specific task. We will focus on how to pass data (input) to functions and how to get results (output) from them.
#
# ## Learning Goals
# By the end of this notebook, students will be able to:
# - Understand the concept of function **arguments** (inputs) and **return values** (outputs).
# - Use built-in functions like `sum()` and `len()`.
# - Pass lists as arguments to functions.
# - Combine function calls to perform calculations.

# %% [markdown]
# ## 1. Using Built-in Functions
# Python comes with many built-in functions that are ready to use. For example, `sum()` calculates the sum of elements in a list, and `len()` returns the number of elements.
#
# **Example:**

# %%
# Calculate the sum of a list directly
print("Sum of [10, 20, 30]:", sum([10, 20, 30]))

# Using a variable as input
lst = [10, 20, 30]
total = sum(lst)
print("Sum of lst:", total)

# Note: Be careful with parentheses! Functions are called using ().
# Out:
# 3

# %% [markdown]
# ## 2. Function Arguments
# Functions can take one or more **arguments** (inputs). In the example above, `lst` is the argument passed to `sum()`.

# %%
# Calculate the length of the list
list_length = len(lst)
print("Length of lst:", list_length)

# Some functions can take multiple arguments, which we will see later.
# Out:
# 20.0

# %% [markdown]
# ## 3. Combining Functions
# You can use the output of one function as the input to another, or combine their results in an expression.

# %%
# Calculate the average of the list
# Average = Sum / Count
average = sum(lst) / len(lst)

print("Average of lst:", average)

# %% [markdown]
# ## 4. Practice Task
# **Exercise:**
# Given the list `lst`, compute the average value.

# %%
lst = [10, 20, 30]

# Your code here:
the_average = sum(lst) / len(lst)

print("The average is:", the_average)

# %% [markdown]
# ## 5. Wrap-Up
# You have learned how to use basic built-in functions to process data. Understanding inputs and outputs is crucial for writing your own functions, which we will cover in future lessons.
