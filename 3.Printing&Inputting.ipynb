# %%
# to print multiple types of data

x = 3
y = 5
#print(x + 'times' + y + 'equals' + x*y )
print(str(x) + ' times ' + str(y) + 'equals ' + str(x*y) )
# Out:
# 3 times 5equals 15

# %%
# If you want to give input to the user in Python, use the input() function.

# input('Feed me a stray cat.') # The output of this function will be a string even if you enter a number.

ans = input('Feed me a stray cat.')

print(ans)

type(ans) # shows the type of the variable

# The input function always returns output as a string.

ans = float(ans)

type(ans)
# Out:
# Feed me a stray cat.6.5
# 6.5
# <class 'str'>
# float

# %%
# Exercise:
# Pythagorean theorem: a**2 + b**2 = c**2
# get two numbers from the user: a,b
# compute and print the length of side c

# %%
side1 = float(input('Length of side a: '))
side2 = float(input('Length of side b: '))

side3 = (side1**2 + side2**2)**(1/2)

print(' ')

print( 'The length of side c is ' + str(side3) )
# Out:
# Length of side a: 3
# Length of side b: 4
#
# The length of side c is 5.0
