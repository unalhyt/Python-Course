# %%
for i in range(10):
  if i%2 == 0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
  if i == 5:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
text = 'HellO, my name is MikE'
# print if the letter is not vowel!!

for i in text:
  if i in 'aeiou': # i.lower()
    continue
  print(i, end='')
# Out:
# HllO, my nm s MkE
