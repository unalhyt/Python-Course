# %%
# Boolean, or logical
# evaluates: True or False
# no other options

boolTrue = True
strTrue = 'True'

# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# boolTrue   bool    True
# strTrue    str     True

# %%
# to make comparison use ==

4 == 4 # asking a question:is left of the sign  equal to right side?

# true is not valid as a boolean. it should be True
# Out:
# True

# %%
4 >= 5
# Out:
# False

# %%
4 != 5 # is 4 not equal to 5?
# Out:
# True

# %%
a = 8
b = 5

outcome = a ==b*2
print(outcome)
# Out:
# False

# %%
# conjuctive comparisons
# and, or
14>5 and 7<10 and 3 == 3 # you can go on
# Out:
# True

# %%
14>5 or 7>10
# Out:
# True

# %%
# convertin any data types into boolean

bool(0) # Only zero value in bool() function will output False
bool(1) # Any number other than zero that will output True.
bool(121454.2365)

# It returns True when any string is entered. It returns False if only the empty string '' is entered.

bool('asd')
bool(' ') # space is not an empty string
bool('')
# Out:
# False

# %%
# Exercise:
# Ask the user for Pythagorean triplets, and test wherher that is a real triplet
# 3, 4, 5
# 5, 12, 13

# The answer will be:
# Your answer is True!! or False!!

# %%
print("Let's test your knowledge of the Pythagorean triplets!")

# First, write code structure as a comment. This way, you can see the outline of the code.

# input the three sides
sidea = float(input('Input length of side a: '))
sideb = float(input('Input length of side b: '))
sidec = float(input('Input length of side c: '))

# Check for accuracy
isPythTriplet = sidea**2 + sideb**2 == sidec**2 # tests the equality of the right side of the equation and sets the result equal to isPythTriplet

# Print the result
print('Your answer is ' + str(isPythTriplet) + '!!')
# Out:
# Let's test your knowledge of the Pythagorean triplets!
# Input length of side a: 5
# Input length of side b: 12
# Input length of side c: 13
# Your answer is True!!
